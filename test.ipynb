# %%
#import own data
import pandas as pd

kashti = pd.read_csv('data.csv')
kashti.head()
# Out:
#   Domain Code                 Domain  Reporter Country Code  \
# 0          TM  Detailed trade matrix                    165
# 1          TM  Detailed trade matrix                    165
# 2          TM  Detailed trade matrix                    165
# 3          TM  Detailed trade matrix                    165
# 4          TM  Detailed trade matrix                    165
#
#   Reporter Countries  Partner Country Code     Partner Countries  \
# 0           Pakistan                   225  United Arab Emirates
# 1           Pakistan                    41       China, mainland
# 2           Pakistan                     2           Afghanistan
# 3           Pakistan                   194          Saudi Arabia
# 4           Pakistan                   114                 Kenya
#
#    Element Code       Element  Year Code  Year      Unit     Value  Ranking
# 0          5922  Export Value       2020  2020  1000 US$  599932.0        1
# ...
